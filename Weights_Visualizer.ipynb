# %%
import os
import pickle as cPickle
from os.path import isfile, join
import sys

# import theano 
import numpy as np 
import matplotlib.pyplot as plt
plt.style.use('ggplot')

# from CNN.CNN import *
from helpers.utilities import SaveData

# %%
def readFile(file_name):
    if(os.path.isfile(file_name)):
        f = open(file_name, 'rb')
        params = cPickle.load(f)
        f.close()
    else:
        print "params not founded"
        sys.exit(0)
    return params

# %%
params_path = 'weights/FCNN-comp1'
params = [40,1]

param_toRead = join(params_path, ('%i.%i.pkl' %(params[0],params[1])))
currentP = readFile(param_toRead)


for i in range(0,len(currentP),2):
    print currentP[i].shape 
    for jdx in range(currentP[i].shape[0]):
        for idx in range(currentP[i][jdx].shape[0]):
            print "i: %i; jdx:%i; idx:%idx" %(i,jdx,idx)
            plt.imshow(currentP[i][jdx][idx], cmap='gray')
            plt.show()
            
#     plt.plot(B, 'g.')
#     plt.subplot(132)
#     plt.plot(BP, 'm.')
#     plt.subplot(133)
#     plt.plot(BUR,'r.')
#     # plt.suptitle('B7')
#     # plt.hist(B7_reshaped, bins=10)
#     plt.show()
# Out:
# (1, 96, 1, 1)
# i: 0; jdx:0; idx:0dx
# i: 0; jdx:0; idx:1dx
# i: 0; jdx:0; idx:2dx
# i: 0; jdx:0; idx:3dx
# i: 0; jdx:0; idx:4dx
# i: 0; jdx:0; idx:5dx
# i: 0; jdx:0; idx:6dx
# i: 0; jdx:0; idx:7dx
# i: 0; jdx:0; idx:8dx
# i: 0; jdx:0; idx:9dx
# i: 0; jdx:0; idx:10dx
# i: 0; jdx:0; idx:11dx
# i: 0; jdx:0; idx:12dx
# i: 0; jdx:0; idx:13dx
# i: 0; jdx:0; idx:14dx
# i: 0; jdx:0; idx:15dx
# i: 0; jdx:0; idx:16dx
# i: 0; jdx:0; idx:17dx
# i: 0; jdx:0; idx:18dx
# i: 0; jdx:0; idx:19dx
# i: 0; jdx:0; idx:20dx
# i: 0; jdx:0; idx:21dx
# i: 0; jdx:0; idx:22dx
# i: 0; jdx:0; idx:23dx
# i: 0; jdx:0; idx:24dx
# i: 0; jdx:0; idx:25dx
# i: 0; jdx:0; idx:26dx
# i: 0; jdx:0; idx:27dx
# i: 0; jdx:0; idx:28dx
# i: 0; jdx:0; idx:29dx
# i: 0; jdx:0; idx:30dx
# i: 0; jdx:0; idx:31dx
# i: 0; jdx:0; idx:32dx
# i: 0; jdx:0; idx:33dx
# i: 0; jdx:0; idx:34dx
# i: 0; jdx:0; idx:35dx
# i: 0; jdx:0; idx:36dx
# i: 0; jdx:0; idx:37dx
# i: 0; jdx:0; idx:38dx
# i: 0; jdx:0; idx:39dx
# i: 0; jdx:0; idx:40dx
# ...
